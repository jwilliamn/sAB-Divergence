# %% [markdown]
# ## Boston Housing Dataset - Outliers added

# %%
import numpy as np
import torch
from torch import nn
from sklearn import datasets
import matplotlib.pyplot as plt
from torch.autograd import Variable

# %%
import numpy as np
from sklearn.datasets import load_boston
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import datasets

from torch.utils.data import Dataset, DataLoader
from torch import nn
import torch

from objectives import KL, Renyi, AB, det_loss
from models import VI

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("whitegrid")

# %%
x, y = load_boston(return_X_y=True)
y_ = y.copy()

scaler = StandardScaler()
x_ = scaler.fit_transform(x)

# %% [markdown]
# Outlier generation and adding to the target variable

# %%
m = 60
x_outlier = np.random.normal(90, 2, m)

y_[10:10+m] = 0.5* x_outlier

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=[20,7])
axs[0].scatter(x_[:,5], y)
axs[1].scatter(x_[:,5], y_)
axs[0].set_title('BostonHD - Original')
axs[1].set_title('BostonHD - with outliers')
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=[20,7])
sns.distplot(y, bins=30, ax=axs[0], label="Y - Original")
sns.distplot(y_, bins=30, ax=axs[1], label='Y - with Outliers')
plt.legend()
plt.show()

# %%
# Train test split of the data
y_ = y_.reshape((len(y_),1))
X_train, X_val, y_train, y_val = train_test_split(x_, y_, test_size=0.2)

# %%
from torch.utils.data import Dataset, DataLoader

# %%
# Tensor format of our dataset
X_train = torch.tensor(X_train, dtype=torch.float)
y_train = torch.tensor(y_train, dtype=torch.float)

X_val = torch.tensor(X_val, dtype=torch.float)
y_val = torch.tensor(y_val, dtype=torch.float)

# %%
Xtrain_loader = DataLoader(X_train, batch_size=50)
ytrain_loader = DataLoader(y_train, batch_size=50)

Xval_loader = DataLoader(X_val, batch_size=50)
yval_loader = DataLoader(y_val, batch_size=50)

# %% [markdown]
# ### Model design

# %%
class VI(nn.Module):
    def __init__(self, n_input=1, n_hidden=10, n_output=1):
        super().__init__()

        self.q_mu = nn.Sequential(
            nn.Linear(n_input, n_hidden*2),
            nn.Linear(n_hidden*2, n_output)
        )
        self.q_log_var = nn.Sequential(
            nn.Linear(n_input, n_hidden*2),
            nn.Linear(n_hidden*2, n_output)
        )

    def reparameterize(self, mu, log_var):
        # std can not be negative, thats why we use log variance
        sigma = torch.exp(0.5 * log_var) + 1e-5
        eps = torch.randn_like(sigma)
        return mu + sigma * eps

    def forward(self, x):
        mu = self.q_mu(x)
        log_var = self.q_log_var(x)
        return self.reparameterize(mu, log_var), mu, log_var

# %%
def train(model, optimizer, criterion, epochs=3000):
    train_losses = []
    validation_losses = []

    for epoch in range(epochs):

        model.train()
        for x, y in zip(Xtrain_loader, ytrain_loader):
            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            y_pred, mu, log_var = model(x)
            loss = -criterion.compute_bound(y_pred, y)
            loss.backward()
            optimizer.step()

            # save loss
            train_losses.append(loss.item())

        model.eval()
        for x, y in zip(Xval_loader, yval_loader):
            y_pred, mu, log_var = model(x)
            loss = -criterion.compute_bound(y_pred, y)

            # save loss
            validation_losses.append(loss.item())

        if epoch%500==0:
            #print('Epoch {:02d}/{} || Loss:  Train {:.4f} | Validation {:.4f}'.format(epoch, epochs, train_losses[-1], validation_losses[-1]))
            print(criterion.qm.data.numpy(), (criterion.softplus(criterion.qs).data**2).numpy())

# %% [markdown]
# ### Model training

# %% [markdown]
# **ELBO**

# %%
# ELBO 
epochs = 5000
m = VI(13, 10, 1)
optimizer = torch.optim.Adam(m.parameters(), lr=0.01)
criterion = torch.nn.MSELoss()


train_losses = []
validation_losses = []

for epoch in range(epochs):
    
    m.train()
    for x, y in zip(Xtrain_loader, ytrain_loader):
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        y_pred, mu, log_var = m(x)
        #loss = criterion(y_pred, y)
        loss = det_loss(y_pred, y, mu, log_var)
        loss.backward()
        optimizer.step()

        # save loss
        train_losses.append(loss.item())
    
    m.eval()
    for x, y in zip(Xval_loader, yval_loader):
        y_pred, mu, log_var = m(x)
        loss = criterion(y_pred, y)

        # save loss
        validation_losses.append(loss.item())
        
    if epoch%500==0:
        print('Epoch {:02d}/{} || Loss:  Train {:.4f} | Validation {:.4f}'.format(epoch, epochs, train_losses[-1], validation_losses[-1]))
# Out:
# Epoch 00/5000 || Loss:  Train 283.3237 | Validation 1176.3447
# Epoch 500/5000 || Loss:  Train 49.0629 | Validation 1505.5525
# Epoch 1000/5000 || Loss:  Train 47.8036 | Validation 1149.5703
# Epoch 1500/5000 || Loss:  Train 27.0330 | Validation 1059.6887
# Epoch 2000/5000 || Loss:  Train 28.7817 | Validation 969.4305
# Epoch 2500/5000 || Loss:  Train 21.3995 | Validation 1231.2894
# Epoch 3000/5000 || Loss:  Train 28.0730 | Validation 1023.0591
# Epoch 3500/5000 || Loss:  Train 26.6218 | Validation 1088.3490
# Epoch 4000/5000 || Loss:  Train 20.0882 | Validation 1220.6118
# Epoch 4500/5000 || Loss:  Train 19.3798 | Validation 1064.0894

# %%
y_pred, _, _ = m(X_train)

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=[20,7])
axs[0].scatter(X_train[:,5], y_train)
axs[1].scatter(X_train[:,5], y_pred.detach().cpu())
axs[0].set_title('BostonHD - Original')
axs[1].set_title('BostonHD - predicted')
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=[20,7])
sns.distplot(y_val, bins=30, ax=axs[0], label="y_train - Original")
sns.distplot(y_pred.detach().cpu(), bins=30, ax=axs[1], label='y_pred - with Outliers')
plt.legend()
plt.show()

# %% [markdown]
# **KL divergence**

# %%
# KL Divergence
epochs = 4000
m = VI(13, 10, 1)
optimizer = torch.optim.Adam(m.parameters(), lr=0.01)
criterion = KL()


train_losses = []
validation_losses = []

train(m, optimizer, criterion, epochs)
# Out:
# [[0.643381]] [[0.61439397]]
# [[0.643381]] [[0.61439397]]
# [[0.643381]] [[0.61439397]]
# [[0.643381]] [[0.61439397]]
# [[0.643381]] [[0.61439397]]
# [[0.643381]] [[0.61439397]]
# [[0.643381]] [[0.61439397]]
# [[0.643381]] [[0.61439397]]

# %%
with torch.no_grad():
    y_pred, _, _ = m(X_train)

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=[20,7])
axs[0].scatter(X_train[:,5], y_train)
axs[1].scatter(X_train[:,5], y_pred.detach().cpu())
axs[0].set_title('BostonHD - Original')
axs[1].set_title('BostonHD - predicted')
plt.show()

# %% [markdown]
# **Renyi divergence**

# %%
# Renyi Divergence
epochs = 5000
m = VI(13, 10, 1)
optimizer = torch.optim.Adam(m.parameters(), lr=0.01)
criterion = Renyi(alpha=0.5, latent_dim=13)

train(m, optimizer, criterion, epochs)
# Out:
# [[0.20575538]] [[0.00349021]]
# [[0.20575538]] [[0.00349021]]
# [[0.20575538]] [[0.00349021]]
# [[0.20575538]] [[0.00349021]]
# [[0.20575538]] [[0.00349021]]
# [[0.20575538]] [[0.00349021]]
# [[0.20575538]] [[0.00349021]]
# [[0.20575538]] [[0.00349021]]
# [[0.20575538]] [[0.00349021]]
# [[0.20575538]] [[0.00349021]]

# %%
with torch.no_grad():
    y_pred, _, _ = m(X_train)

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=[20,7])
axs[0].scatter(X_train[:,5], y_train)
axs[1].scatter(X_train[:,5], y_pred.detach().cpu())
axs[0].set_title('BostonHD - Original')
axs[1].set_title('BostonHD - predicted')
plt.show()

# %% [markdown]
# ### AB Divergence

# %%
# AB Divergence
epochs = 5000
m = VI(13, 10, 1)
optimizer = torch.optim.Adam(m.parameters(), lr=0.01)
criterion = AB(alpha = 1.2, beta = -0.25, latent_dim=13)

train(m, optimizer, criterion, epochs)
# Out:
# [[0.27736431]] [[0.21396797]]
# [[0.27736431]] [[0.21396797]]
# [[0.27736431]] [[0.21396797]]
# [[0.27736431]] [[0.21396797]]
# [[0.27736431]] [[0.21396797]]
# [[0.27736431]] [[0.21396797]]
# [[0.27736431]] [[0.21396797]]
# [[0.27736431]] [[0.21396797]]
# [[0.27736431]] [[0.21396797]]
# [[0.27736431]] [[0.21396797]]

# %%
with torch.no_grad():
    y_pred, _, _ = m(X_train)

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=[20,7])
axs[0].scatter(X_train[:,5], y_train)
axs[1].scatter(X_train[:,5], y_pred.detach().cpu())
axs[0].set_title('BostonHD - Original')
axs[1].set_title('BostonHD - predicted')
plt.show()
